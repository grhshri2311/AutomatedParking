# %%
from PIL import Image, ImageDraw
from IPython.display import display

# The program we will be finding faces on the example below

# %%
import face_recognition
import numpy as np

# %%
shriram = face_recognition.load_image_file("appa.jpg")
shriram_face_encoding = face_recognition.face_encodings(shriram)[0]

# %%
known_face_encodings = [
    shriram_face_encoding
]
known_face_names = [
    "Shriram"
]
print('Learned encoding for', len(known_face_encodings), 'images.')
# Out:
# Learned encoding for 1 images.

# %%
import cv2
import numpy as np
import face_recognition

# %%
vid = cv2.VideoCapture("vedio.mp4")
  
while(True):
      
    # Capture the video frame
    # by frame
    ret, frame = vid.read()
    
    process_this_frame =True
    if process_this_frame:
        face_locations = face_recognition.face_locations(frame)
        face_encodings = face_recognition.face_encodings(frame, face_locations)
        # Initialize an array for the name of the detected users
        face_names = []
        for face_encoding in face_encodings:
            # See if the face is a match for the known face(s)
            matches = face_recognition.compare_faces(known_face_encodings, face_encoding)
            name = "Unknown"
        # check the known face with the smallest distance to the new face
            face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
        # Take the best one
            best_match_index = np.argmin(face_distances)
        # If we have a match
            if matches[best_match_index]:
        # Save the name of the best match
                name = known_face_names[best_match_index]
                face_names.append(name)
        process_this_frame = not process_this_frame
      
        for (top, right, bottom, left), name in zip(face_locations, face_names):
            top *= 4
            right *= 4
            bottom *= 4
            left *= 4
        # Draw a box around the face
            cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)
        # Define the font of the name
            font = cv2.FONT_HERSHEY_DUPLEX
        # Display the name
            cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

  
    # Display the resulting frame
    cv2.imshow('frame', frame)
      
    # the 'q' button is set as the
    # quitting button you may use any
    # desired button of your choice
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
  
# After the loop release the cap object
vid.release()
# Destroy all the windows
cv2.destroyAllWindows()

# %%
import face_recognition
import numpy as np
from PIL import Image, ImageDraw
from IPython.display import display

# This is an example of running face recognition on a single image
# and drawing a box around each person that was identified.

# Load a sample picture and learn how to recognize it.
obama_image = face_recognition.load_image_file("shriram.jpg")
obama_face_encoding = face_recognition.face_encodings(obama_image)[0]

# Load a second sample picture and learn how to recognize it.
biden_image = face_recognition.load_image_file("rani.jpg")
biden_face_encoding = face_recognition.face_encodings(biden_image)[0]

# Load a sample picture and learn how to recognize it.
obama_image1 = face_recognition.load_image_file("appa.jpg")
obama_face_encoding1 = face_recognition.face_encodings(obama_image1)[0]

# Load a second sample picture and learn how to recognize it.
biden_image1 = face_recognition.load_image_file("hari.jpg")
biden_face_encoding1 = face_recognition.face_encodings(biden_image1)[0]

# Create arrays of known face encodings and their names
known_face_encodings = [
    obama_face_encoding,
    biden_face_encoding,
    obama_face_encoding1,
    biden_face_encoding1
]
known_face_names = [
    "Shriram",
    "Rani",
    "appa",
    "hari"q
]
print('Learned encoding for', len(known_face_encodings), 'images.')
# Out:
# Learned encoding for 4 images.

# %%
video_capture = cv2.VideoCapture(0)


while True:
    # Capture frame-by-frame
    ret, frame = video_capture.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(200, 200),
        flags=cv2.CASCADE_SCALE_IMAGE
    )
    
    face_encodings = face_recognition.face_encodings(frame,faces)

    known_face_encodings.append(face_encodings)
    known_face_names.append("Shriram")
    # Draw a rectangle around the faces
    for i,(x, y, w, h) in enumerate(faces):
       
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 3)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        cv2.putText(frame,"Shriram",(x, y), font, 2,(255,0,0),5)

        smile = smileCascade.detectMultiScale(
            roi_gray,
            scaleFactor= 1.16,
            minNeighbors=35,
            minSize=(25, 25),
            flags=cv2.CASCADE_SCALE_IMAGE
        )

        for (sx, sy, sw, sh) in smile:
            cv2.rectangle(roi_color, (sh, sy), (sx+sw, sy+sh), (255, 0, 0), 2)
            cv2.putText(frame,'Smile',(x + sx,y + sy), 1, 1, (0, 255, 0), 1)

        eyes = eyeCascade.detectMultiScale(roi_gray)
        for (ex,ey,ew,eh) in eyes:
            cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
            cv2.putText(frame,'Eye',(x + ex,y + ey), 1, 1, (0, 255, 0), 1)

    cv2.putText(frame,'Number of Faces : ' + str(len(faces)),(40, 40), font, 1,(255,0,0),2)      
    # Display the resulting frame
    cv2.imshow('Video', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
      break

# When everything is done, release the capture
video_capture.release()
cv2.destroyAllWindows()

# %%
import cv2

cascPath = "P:\\Users\\Luckylad_20\\Anaconda3\\Lib\\site-packages\\cv2\\data\\haarcascade_frontalface_default.xml"
eyePath = "P:\\Users\\Luckylad_20\\Anaconda3\\Lib\\site-packages\\cv2\\data\\haarcascade_eye.xml"
smilePath = "P:\\Users\\Luckylad_20\\Anaconda3\\Lib\\site-packages\\cv2\\data\\haarcascade_smile.xml"

faceCascade = cv2.CascadeClassifier(cascPath)
eyeCascade = cv2.CascadeClassifier(eyePath)
smileCascade = cv2.CascadeClassifier(smilePath)

font = cv2.FONT_HERSHEY_SIMPLEX

# %%
video_capture = cv2.VideoCapture(0)


while True:
    # Capture frame-by-frame
    ret, frame = video_capture.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(200, 200),
        flags=cv2.CASCADE_SCALE_IMAGE
    )
    
    face_encodings = face_recognition.face_encodings(frame,faces)

    # Draw a rectangle around the faces
    for i,(x, y, w, h) in enumerate(faces):
    
        matches = face_recognition.compare_faces(known_face_encodings, face_encodings[i])
        name = "Unknown"

        # Or instead, use the known face with the smallest distance to the new face
        face_distances = face_recognition.face_distance(known_face_encodings, face_encodings[i])
        best_match_index = np.argmin(face_distances)
        if matches[best_match_index]:
            name = known_face_names[best_match_index]
        print("name")
        
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 3)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        cv2.putText(frame,name,(x, y), font, 2,(255,0,0),5)

        smile = smileCascade.detectMultiScale(
            roi_gray,
            scaleFactor= 1.16,
            minNeighbors=35,
            minSize=(25, 25),
            flags=cv2.CASCADE_SCALE_IMAGE
        )

        for (sx, sy, sw, sh) in smile:
            cv2.rectangle(roi_color, (sh, sy), (sx+sw, sy+sh), (255, 0, 0), 2)
            cv2.putText(frame,'Smile',(x + sx,y + sy), 1, 1, (0, 255, 0), 1)

        eyes = eyeCascade.detectMultiScale(roi_gray)
        for (ex,ey,ew,eh) in eyes:
            cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
            cv2.putText(frame,'Eye',(x + ex,y + ey), 1, 1, (0, 255, 0), 1)

    cv2.putText(frame,'Number of Faces : ' + str(len(faces)),(40, 40), font, 1,(255,0,0),2)      
    # Display the resulting frame
    cv2.imshow('Video', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
      break

# When everything is done, release the capture
video_capture.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-2c84ae0b1e41> in <module>
#      21     for i,(x, y, w, h) in enumerate(faces):
#      22
# ---> 23         matches = face_recognition.compare_faces(known_face_encodings, face_encodings[i])
#      24         name = "Unknown"
#      25
#
# P:\Users\Luckylad_20\Anaconda3\lib\site-packages\face_recognition\api.py in compare_faces(known_face_encodings, face_encoding_to_check, tolerance)
#     224     :return: A list of True/False values indicating which known_face_encodings match the face encoding to check
#     225     """
# --> 226     return list(face_distance(known_face_encodings, face_encoding_to_check) <= tolerance)
#
# P:\Users\Luckylad_20\Anaconda3\lib\site-packages\face_recognition\api.py in face_distance(face_encodings, face_to_compare)
#      73         return np.empty((0))
#      74
# ...

# %%
gray = face_recognition.load_image_file("family.jpg")
plt.imshow(gray,cmap='gray')
plt.show()

# %%
faces = faceCascade.detectMultiScale(
gray,
scaleFactor=1.1,
minNeighbors=5,
flags=cv2.CASCADE_SCALE_IMAGE
)
# For each face
for (x, y, w, h) in faces: 
    # Draw rectangle around the face
    cv2.rectangle(gray, (x, y), (x+w, y+h), (255, 255, 255), 3)
face_encodings = face_recognition.face_encodings(frame,faces)    
plt.imshow(gray)
plt.show()
# Out:
# [[2093  520  482  482]
#  [2605  453  747  747]
#  [ 744  672  465  465]
#  [1487  472  447  447]]

# %%
known_face_encodings = [
    face_encodings[0],
    face_encodings[1],
    face_encodings[2],
    face_encodings[3]
    
]
known_face_names = [
    "Shriram",
    "Hari",
    "appa",
    "amma"
]
print('Learned encoding for', len(known_face_encodings), 'images.')
# Out:
# Learned encoding for 4 images.

# %%
gray = face_recognition.load_image_file("family.jpg")
faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(200, 200),
        flags=cv2.CASCADE_SCALE_IMAGE
    )
print(len(faces))
# Out:
# 4

# %%
face_encodings = face_recognition.face_encodings(frame, faces)
        # Initialize an array for the name of the detected users
for i,face_encoding in enumerate(face_encodings):
            x,y,w,h = faces[i]
            # See if the face is a match for the known face(s)
            matches = face_recognition.compare_faces(known_face_encodings, face_encoding)
            name = "Unknown"
        # check the known face with the smallest distance to the new face
            face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
        # Take the best one
            best_match_index = np.argmin(face_distances)
        # If we have a match
            if matches[best_match_index]:
        # Save the name of the best match
                name = known_face_names[best_match_index]
        
            cv2.rectangle(gray, (x, y), (x+w, y+h), (255, 0, 0), 3)
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = gray[y:y+h, x:x+w]
            cv2.putText(gray,name,(x, y), font, 2,(255,0,0),5)

# %%
plt.figure(figsize=(12,8))
plt.imshow(gray)
plt.show()

# %%
import dlib
import numpy as np
from scipy import misc
# Models Loaded
face_detector = dlib.get_frontal_face_detector()
pose_predictor_68_point = dlib.shape_predictor('../models/shape_predictor_68_face_landmarks.dat')
face_encoder = dlib.face_recognition_model_v1('../models/dlib_face_recognition_resnet_model_v1.dat')
def whirldata_face_detectors(img, number_of_times_to_upsample=1):
 return face_detector(img, number_of_times_to_upsample)
def whirldata_face_encodings(face_image,num_jitters=1):
 face_locations = whirldata_face_detectors(face_image)
 pose_predictor = pose_predictor_68_point
 predictors = [pose_predictor(face_image, face_location) for face_location in face_locations]
 return [np.array(face_encoder.compute_face_descriptor(face_image, predictor, num_jitters)) for predictor in predictors][0]
known_image = misc.imread("ano.jpeg")
print(known_image.shape)
enc = whirldata_face_encodings(known_image)
print(enc)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-e9512af8adf4> in <module>
#       4 # Models Loaded
#       5 face_detector = dlib.get_frontal_face_detector()
# ----> 6 pose_predictor_68_point = dlib.shape_predictor('../models/shape_predictor_68_face_landmarks.dat')
#       7 face_encoder = dlib.face_recognition_model_v1('../models/dlib_face_recognition_resnet_model_v1.dat')
#       8 def whirldata_face_detectors(img, number_of_times_to_upsample=1):
#
# RuntimeError: Unable to open ../models/shape_predictor_68_face_landmarks.dat

# %%
known_face_names = known_face_names[0:5]
known_face_encodings =known_face_encodings[:5]
len(known_face_encodings)
# Out:
# 5

# %%
from __future__ import print_function
import requests
import json
import cv2

addr = 'http://192.168.43.34:5000'
test_url = addr + '/api/test'

# prepare headers for http request
content_type = 'image/jpeg'
headers = {'content-type': content_type}

img = cv2.imread('shriram.jpg')
# encode image as jpeg
_, img_encoded = cv2.imencode('.jpg', img)
# send http request with image and receive response
response = requests.post(test_url, data=img_encoded.tostring(), headers=headers)
# decode response
print(json.loads(response.text))
# Out:
# {'message': 'image received. size=292x584'}

# %%
shriram_face_encoding[2]
# Out:
# 0.10632336139678955
